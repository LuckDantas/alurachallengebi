# %%
import pandas as pd

# %%
dispositivos = pd.read_json('data/Tabela_dispositivos.json')
idade = pd.read_json('data/Tabela_idade_e_genero.json')

# %%
dispositivos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 819 entries, 0 to 818
# Data columns (total 17 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   Dia                                        819 non-null    object
#  1   Plataforma do dispositivo                  819 non-null    object
#  2   Colocação                                  819 non-null    object
#  3   Plataforma                                 819 non-null    object
#  4   Alcance                                    742 non-null    float64
#  5   Impressões                                 812 non-null    float64
#  6   Quantia gasta (BRL)                        819 non-null    float64
#  7   Cliques em links                           819 non-null    object
#  8   Visualizações por página                   819 non-null    object
#  9   Compras no website                         819 non-null    object
# ...

# %%
dispositivos.head()
# Out:
#           Dia Plataforma do dispositivo Colocação Plataforma  Alcance  \
# 0  2021-07-31                       All       All        All  12440.0
# 1  2021-07-31                mobile_web       All        All    104.0
# 2  2021-07-31                mobile_web      feed        All    104.0
# 3  2021-07-31                mobile_web      feed   facebook    104.0
# 4  2021-07-31                mobile_app       All        All  12236.0
#
#    Impressões Quantia gasta (BRL) Cliques em links Visualizações por página  \
# 0     16114.0               72,66           141,00                   101,00
# 1       170.0                0,49
# 2       170.0                0,49
# 3       170.0                0,49
# 4     15679.0               70,62           136,00                    98,00
#
#   Compras no website Compras no facebook Adicionados ao carrinho  \
# 0               6,00                                       48,00
# 1
# 2
# 3
# 4               6,00                                       48,00
# ...

# %%
idade.head()
# Out:
#    Idade     Gênero         Dia FIELD4  Alcance  Impressões  \
# 0  45-54   Feminino  2021-07-31          1116.0      1489.0
# 1  35-44     Outros  2021-07-31             4.0         5.0
# 2  45-54     Outros  2021-07-31             3.0         3.0
# 3    65+  Masculino  2021-07-31            24.0        36.0
# 4     25     Outros  2021-07-31             4.0         4.0
#
#    Quantia gasta (BRL) Cliques no link Visualizações por página  \
# 0                 9.42           24,00                    20,00
# 1                 0.03
# 2                 0.00
# 3                 0.11
# 4                 0.01
#
#   Compras no website Compras no facebook Adicionados ao carrinho  \
# 0                                                           1,00
# 1
# 2
# 3
# 4
#
#   Valor de conversão adicionado ao carrinho Checkouts Iniciados  \
# 0                                     63,90                1,00
# 1
# 2
# 3
# 4
#
# ...

# %%
idade['Quantia gasta (BRL)'] = idade['Quantia gasta (BRL)'].replace('',0)
#idade['Quantia gasta (BRL)'] = idade['Quantia gasta (BRL)'].astype(float, errors = 'ignore')

idade['Quantia gasta (BRL)'] = idade['Quantia gasta (BRL)'].str.replace(',', '.')
idade['Quantia gasta (BRL)'] = idade['Quantia gasta (BRL)'].astype(float)
idade['Quantia gasta (BRL)'] = idade['Quantia gasta (BRL)'].fillna(value=0)

#Dispositivos

dispositivos['Quantia gasta (BRL)'] = dispositivos['Quantia gasta (BRL)'].replace('',0)
#idade['Quantia gasta (BRL)'] = idade['Quantia gasta (BRL)'].astype(float, errors = 'ignore')

dispositivos['Quantia gasta (BRL)'] = dispositivos['Quantia gasta (BRL)'].str.replace(',', '.')
dispositivos['Quantia gasta (BRL)'] = dispositivos['Quantia gasta (BRL)'].astype(float)
dispositivos['Quantia gasta (BRL)'] = dispositivos['Quantia gasta (BRL)'].fillna(value=0)

# %%
idade['Quantia gasta (BRL)'].head()
# Out:
# 0    9.42
# 1    0.03
# 2    0.00
# 3    0.11
# 4    0.01
# Name: Quantia gasta (BRL), dtype: float64

# %%
print('Valor Gasto na tabela idade:', idade['Quantia gasta (BRL)'].sum())
# Out:
# Valor Gasto na tabela idade: 3125.43

# %%
print('Valor Gasto na tabela dispositivos:', dispositivos['Quantia gasta (BRL)'].sum())
# Out:
# Valor Gasto na tabela dispositivos:% 12501.72

# %%
dispositivos.Compras.unique()
# Out:
# array(['6,00', '', '1,00', '4,00', '3,00', '5,00', '13,00', '10,00',
#        '7,00', '2,00', '9,00', '8,00', '11,00', '12,00', '15,00', '14,00',
#        '19,00', '17,00', '16,00', '23,00', '21,00', '20,00', '18,00'],
#       dtype=object)
